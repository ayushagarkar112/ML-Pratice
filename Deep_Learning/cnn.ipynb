# %% [markdown]
# Convolutional Nerual Network

# %% [markdown]
# Importing the Liblaries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.21.0'

# %% [markdown]
# Part 1- Data Preprocessing

# %% [markdown]
# Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
 )

training_set = train_datagen.flow_from_directory(
  '/home/ayush/Desktop/ML-Pratice/dataset/training_set',
  target_size = (64, 64),
  batch_size = 32,
  class_mode = 'binary'
  )
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
validation_generator = test_datagen.flow_from_directory(
    '/home/ayush/Desktop/ML-Pratice/dataset/test_set',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# Part 2 - Building the CNN

# %% [markdown]
# Initialisng the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu', input_shape = [64, 64, 3]))
# Out:
# /home/ayush/Desktop/ML-Pratice/ml/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1777956170.603092    5207 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# Step 2 -pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# Adding a second Convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size = 3, activation = 'relu', input_shape = [64, 64, 3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size = 2, strides = 2))

# %% [markdown]
# Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation = 'relu'))

# %% [markdown]
# Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation = 'sigmoid'))

# %% [markdown]
# Part 3 - Training the CNN

# %% [markdown]
# Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = validation_generator, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 102s 406ms/step - accuracy: 0.6095 - loss: 0.6578 - val_accuracy: 0.6810 - val_loss: 0.5979
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 137s 389ms/step - accuracy: 0.6840 - loss: 0.5897 - val_accuracy: 0.7235 - val_loss: 0.5593
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 375ms/step - accuracy: 0.7211 - loss: 0.5472 - val_accuracy: 0.7335 - val_loss: 0.5358
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 59s 235ms/step - accuracy: 0.7355 - loss: 0.5227 - val_accuracy: 0.7200 - val_loss: 0.5666
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.7624 - loss: 0.4895 - val_accuracy: 0.7695 - val_loss: 0.4938
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.7739 - loss: 0.4740 - val_accuracy: 0.7700 - val_loss: 0.4858
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.7839 - loss: 0.4568 - val_accuracy: 0.7765 - val_loss: 0.4857
# Epoch 8/25
# ...

# %% [markdown]
# Part 4 -Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image

pth = '/home/ayush/Desktop/ML-Pratice/dataset/testing/Dog1.avif'

test_image = image.load_img(pth, target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = test_image / 255.0   # IMPORTANT
test_image = np.expand_dims(test_image, axis=0)

result = cnn.predict(test_image)

print(result)  # debug

if result[0][0] > 0.7:
    prediction = 'dog'
else:
    prediction = 'cat'

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[0.9495605]]
# dog
