# %% [markdown]
# K Means Clustering

# %% [markdown]
# Importing Liblaries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the dataset

# %%
dataset=pd.read_csv(r"D:\python\ML & AI Pratice\Datasets\Mall_Customers.csv")
# Using only Annual Income and Spending Score for K-Means
# Skipping CustomerID (identifier), Genre (categorical), Age (not needed here)
X=dataset.iloc[:,[3,4]].values

# %% [markdown]
# Using Elbow method to find optimal number of clusters

# %% [markdown]
# Training K means model on dataset

# %% [markdown]
# Visualising the dataset
